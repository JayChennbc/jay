# %%
# --- KEPLER --- Homework9
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
df = pd.read_csv("solar_system.csv")
df = df.set_index(["Attribute"])
df
# Out:
#                             Mercury    Venus  Earth   Moon   Mars  Jupiter  \
# Attribute
# Mass (10^24kg)                0.330     4.87   5.97  0.073  0.642     1898
# Diameter (km)                  4879    12104  12756   3475   6792   142984
# Density (kg/m^3)               5429     5243   5514   3340   3934     1326
# Gravity (m/s^2)                 3.7      8.9    9.8    1.6    3.7     23.1
# Escape Velocity (km/s)          4.3     10.4   11.2    2.4    5.0     59.5
# Rotation Period (hours)      1407.6  -5832.5   23.9  655.7   24.6      9.9
# Length of Day (hours)        4222.6   2802.0   24.0  708.7   24.7      9.9
# Distance from Sun (10^6 km)    57.9    108.2  149.6  0.384  228.0    778.5
# Perihelion (10^6 km)           46.0    107.5  147.1  0.363  206.7    740.6
# Aphelion (10^6 km)             69.8    108.9  152.1  0.406  249.3    816.4
# Orbital Period (days)          88.0    224.7  365.2   27.3  687.0     4331
# ...

# %%
df.shape  #20 rows by 11 columns
# Out:
# (20, 10)

# %%
df.head()
# Out:
#                        Mercury  Venus  Earth   Moon   Mars Jupiter  Saturn  \
# Attribute
# Mass (10^24kg)           0.330   4.87   5.97  0.073  0.642    1898     568
# Diameter (km)             4879  12104  12756   3475   6792  142984  120536
# Density (kg/m^3)          5429   5243   5514   3340   3934    1326     687
# Gravity (m/s^2)            3.7    8.9    9.8    1.6    3.7    23.1     9.0
# Escape Velocity (km/s)     4.3   10.4   11.2    2.4    5.0    59.5    35.5
#
#                        Uranus Neptune   Pluto
# Attribute
# Mass (10^24kg)           86.8     102  0.0130
# Diameter (km)           51118   49528    2376
# Density (kg/m^3)         1270    1638    1850
# Gravity (m/s^2)           8.7    11.0     0.7
# Escape Velocity (km/s)   21.3    23.5     1.3

# %%
df.tail()
# Out:
#                         Mercury Venus Earth Moon  Mars  Jupiter   Saturn  \
# Attribute
# Mean Temperature (C)        167   464    15  -20   -65     -110     -140
# Surface Pressure (bars)       0    92     1    0  0.01  Unknown  Unknown
# Number of Moons               0     0     1    0     2       95      274
# Ring System?                 No    No    No   No    No      Yes      Yes
# Global Magnetic Field?      Yes    No   Yes   No    No      Yes      Yes
#
#                           Uranus  Neptune    Pluto
# Attribute
# Mean Temperature (C)        -195     -200     -225
# Surface Pressure (bars)  Unknown  Unknown  0.00001
# Number of Moons               28       16        5
# Ring System?                 Yes      Yes       No
# Global Magnetic Field?       Yes      Yes  Unknown

# %%
print(df.columns)
# Out:
# Index(['Mercury', 'Venus', 'Earth', 'Moon', 'Mars', 'Jupiter', 'Saturn',
#        'Uranus', 'Neptune', 'Pluto'],
#       dtype='object')

# %%
print(df['Attribute'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Attribute'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(df['Attribute'])
#
# ...

# %%
orbital_period =df.iloc[10].astype(float)
perihelion = df.iloc[8].astype(float)
aphelion = df.iloc[9].astype(float)

# %%
# Perihelion is the closest point to the object being orbited along a planet's orbital path.
# Aphelion is the furthest point to the object being orbited along a planet's orbital path.
# The semi-major axis is the radius of the longest diameter in the orbital path.

# %%
semimajor = (perihelion + aphelion)/2
print(semimajor)
# Out:
# Mercury      57.9000
# Venus       108.2000
# Earth       149.6000
# Moon          0.3845
# Mars        228.0000
# Jupiter     778.5000
# Saturn     1432.0500
# Uranus     2867.0500
# Neptune    4515.0000
# Pluto      5906.3500
# dtype: float64

# %%
df = pd.read_csv("solar_system.csv")
df = df.set_index(["Attribute"])
df
# Out:
#                             Mercury    Venus  Earth   Moon   Mars  Jupiter  \
# Attribute
# Mass (10^24kg)                0.330     4.87   5.97  0.073  0.642     1898
# Diameter (km)                  4879    12104  12756   3475   6792   142984
# Density (kg/m^3)               5429     5243   5514   3340   3934     1326
# Gravity (m/s^2)                 3.7      8.9    9.8    1.6    3.7     23.1
# Escape Velocity (km/s)          4.3     10.4   11.2    2.4    5.0     59.5
# Rotation Period (hours)      1407.6  -5832.5   23.9  655.7   24.6      9.9
# Length of Day (hours)        4222.6   2802.0   24.0  708.7   24.7      9.9
# Distance from Sun (10^6 km)    57.9    108.2  149.6  0.384  228.0    778.5
# Perihelion (10^6 km)           46.0    107.5  147.1  0.363  206.7    740.6
# Aphelion (10^6 km)             69.8    108.9  152.1  0.406  249.3    816.4
# Orbital Period (days)          88.0    224.7  365.2   27.3  687.0     4331
# ...

# %%
new_row = pd.Series(semimajor)
df.loc[len(df)] = new_row
df = df.rename({20: "Semi-major Axis (10^6 km)"})
df = df.drop([23,25])
df
# Out:
#                             Mercury    Venus  Earth    Moon   Mars  Jupiter  \
# Attribute
# Mass (10^24kg)                0.330     4.87   5.97   0.073  0.642     1898
# Diameter (km)                  4879    12104  12756    3475   6792   142984
# Density (kg/m^3)               5429     5243   5514    3340   3934     1326
# Gravity (m/s^2)                 3.7      8.9    9.8     1.6    3.7     23.1
# Escape Velocity (km/s)          4.3     10.4   11.2     2.4    5.0     59.5
# Rotation Period (hours)      1407.6  -5832.5   23.9   655.7   24.6      9.9
# Length of Day (hours)        4222.6   2802.0   24.0   708.7   24.7      9.9
# Distance from Sun (10^6 km)    57.9    108.2  149.6   0.384  228.0    778.5
# Perihelion (10^6 km)           46.0    107.5  147.1   0.363  206.7    740.6
# Aphelion (10^6 km)             69.8    108.9  152.1   0.406  249.3    816.4
# Orbital Period (days)          88.0    224.7  365.2    27.3  687.0     4331
# ...

# %%
df.shape # 21 rows, 10 columns
# Out:
# (21, 10)

# %%
orbital_period =df.iloc[10].astype(float)
semi_major_axis =df.iloc[20].astype(float)

plt.figure()
x = semi_major_axis
y = orbital_period
plt.scatter(x, y, label = 'data')
plt.title("Semi-major Axis vs Orbital Period")
plt.xlabel = "Semi-major Axis (10^6 km)"
plt.ylabel = "Orbital Period (days)"
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def keplers_third_law(a, m):
    return m*a**1.5

# %%
popt, pcov = curve_fit(keplers_third_law, x, y)
m_fit = popt
print(f" Kepler's Third Law: m_fit = {m_fit[0]:.2f}")
# Out:
#  Kepler's Third Law: m_fit = 0.20

# %%
residuals = y - keplers_third_law(x, m_fit)
chi2 = np.sum(residuals**2)
dof = len(x) - len(popt)
chi2_squared = chi2/dof

# %%
plt.figure()
x = semi_major_axis
y = orbital_period
plt.scatter(x, y, label = 'data')
plt.title(f"Semi-major Axis vs Orbital Period with Reduced chi_squared: {chi2_squared:.2f}")
plt.xlabel = "Semi-major Axis (10^6 km)"
plt.ylabel = "Orbital Period (days)"

#best fit curve
plt.plot(x, keplers_third_law(x, m_fit), color = 'red', label='Best fit curve')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.to_csv("kepler.csv", index=False)
